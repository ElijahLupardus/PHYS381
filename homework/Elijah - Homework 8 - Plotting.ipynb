# %% [markdown]
# # Plotting Practice
#
# ## HW 8 - 01: Energy in a Chaotic Pendulum

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Step 1: load the csv file
df = pd.read_csv("/home/cmckay/clusters/CQM/0.0-0.0-9.371069245283019-0.0.csv")
#this will set time as our index
df = df.set_index('time')
df.head()
# Out:
#           thetadot_0(t)  thetadot_1(t)  theta_0(t)  theta_1(t)    p_0(t)  \
# time
# 0.000000       9.371069       0.000000    0.000000    0.000000  4.685535
# 0.010001       9.312319       0.099358    0.093523    0.000333  4.680891
# 0.020002       9.144896       0.382412    0.185901    0.002602  4.666449
# 0.030003       8.890850       0.810973    0.276150    0.008468  4.640948
# 0.040004       8.576021       1.338490    0.363534    0.019153  4.602986
#
#             p_1(t)         V          T          L          E       V_1  \
# time
# 0.000000  2.342767  0.000000  21.954235  21.954235  21.954235  0.000000
# 0.010001  2.342818  0.042871  21.911364  21.868493  21.954235  0.021436
# 0.020002  2.343528  0.169042  21.785193  21.616151  21.954235  0.084529
# 0.030003  2.346297  0.371855  21.582380  21.210525  21.954235  0.186015
# 0.040004  2.352742  0.642021  21.312213  20.670192  21.954235  0.321460
#
#                V_0          H        T_0        T_1
# time
# 0.000000  0.000000  21.954235  10.977117  10.977117
# 0.010001  0.021435  21.954235  10.839910  11.071454
# 0.020002  0.084513  21.954235  10.453640  11.331553
# 0.030003  0.185840  21.954235   9.880903  11.701477
# 0.040004  0.320561  21.954235   9.193518  12.118696

# %%
#Step 2: create the plot
# %matplotlib inline

#create an empty plot
fig, ax = plt.subplots(1)

#sizes
fig.set_figwidth(12)
fig.set_figheight(9)

#plot data
##This line is giving me trouble. I'm not sure how to define the time here
time = df.index.values
E = df['E'].values
#same for V and T

#Now Enter the columns that you want
df['T'].plot(label='Kinetic')
df['V'].plot(label='Potential')
df['E'].plot(label='Total Energy')


#Step 3: zooming in with x limits
ax.set_xlim(70, 75)

#Annotations
ax.set_title('Energy in a Chaotic Double Pendulum')
ax.set_xlabel('time (s)')
ax.set_ylabel('Energy (J)')
ax.text(72, -1, "source data: 0.0-0.0-9.371069245283019-0.0.csv", alpha= 0.7)

#Legend
ax.legend(loc= "upper left", bbox_to_anchor= (1,1))

#saving the plot
plt.savefig("Lupardus-HW8-01.png")

# %% [markdown]
# ## Notes on plot creation - Feb 9

# %% [markdown]
# A general rule of thumb for line plots:
#
# slopes of important lines should be about 1 (45 degrees)
#
# This helps you see the variation in the plot

# %% [markdown]
# # Here we will start the second plot
# ## HW 8 - 02: QHO

# %% [markdown]
# you cannot set the values of the horizontal lines, you will have to choose values that are evenly spread, and label them as werner has a nose and a half (h is hbar). This is purely for demonstrative value

# %%
x = np.linspace(-4,4,100)

#potential parabola
V = x**2/2

#setting up the plot
fig, ax = plt.subplots(1)
fig.set_figwidth(9)
fig.set_figheight(12)
ax.plot(x,V)
#take the axis and frame off
ax.set_frame_on(False)
ax.set_axis_off()

#drawing the horizontal lines(energy levels)
for n in range(0,8):
    En = n + 0.5
    ax.plot([-8,8], [En,En], color="gray", )
    plt.text(4, En, '$E_{} = \omega\hbar({} + 1/2)$'.format(n,n), fontsize = 14, verticalalignment='bottom')
#omega and hbar are set to 1 here
